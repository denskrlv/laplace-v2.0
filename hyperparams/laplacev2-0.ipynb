# %% [markdown]
# # Hyperparameter sensitivity experiment
# This notebook conducts a post-hoc Laplace approximation hyperparameter sensitivity analysis on pre-trained Lenet and ResNet18 models trained on MNIST.

# %% [markdown]
# > Disclaimer: This code was run on Kaggle

# %%
# !pip install torch
# !pip install numpy
# !pip install torchmetrics
# !pip install torchvision
# !pip install tqdm
# !pip install seaborn
# !pip install matplotlib
# !pip install backpack
# !pip install curvlinops-for-pytorch
# !pip install backpack-for-pytorch
# !pip install asdfghjkl
# !pip install pandas
# !pip install git+https://git@github.com/wiseodd/asdl@asdfghjkl
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 11.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
#     Uninstalling nvidia-curand-cu12-10.3.10.19:
#       Successfully uninstalled nvidia-curand-cu12-10.3.10.19
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.4.0.6
#     Uninstalling nvidia-cufft-cu12-11.4.0.6:
#       Successfully uninstalled nvidia-cufft-cu12-11.4.0.6
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.9.0.13
#     Uninstalling nvidia-cublas-cu12-12.9.0.13:
#       Successfully uninstalled nvidia-cublas-cu12-12.9.0.13
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.9.5
#     Uninstalling nvidia-cusparse-cu12-12.5.9.5:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.9.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.4.40
#     Uninstalling nvidia-cusolver-cu12-11.7.4.40:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.4.40
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy) (2024.2.0)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.11/dist-packages (1.7.1)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (2.6.0+cu124)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics) (0.14.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.2.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.13.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>1.20.0->torchmetrics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>1.20.0->torchmetrics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>1.20.0->torchmetrics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>1.20.0->torchmetrics) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>1.20.0->torchmetrics) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>1.20.0->torchmetrics) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>1.20.0->torchmetrics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>1.20.0->torchmetrics) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>1.20.0->torchmetrics) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>1.20.0->torchmetrics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>1.20.0->torchmetrics) (2024.2.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.6.0+cu124)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0->torchvision) (1.3.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.6.0->torchvision) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy!=1.24.0,>=1.17->seaborn) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy!=1.24.0,>=1.17->seaborn) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy!=1.24.0,>=1.17->seaborn) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy!=1.24.0,>=1.17->seaborn) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy!=1.24.0,>=1.17->seaborn) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy!=1.24.0,>=1.17->seaborn) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy!=1.24.0,>=1.17->seaborn) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy!=1.24.0,>=1.17->seaborn) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy!=1.24.0,>=1.17->seaborn) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy!=1.24.0,>=1.17->seaborn) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy!=1.24.0,>=1.17->seaborn) (2024.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->matplotlib) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->matplotlib) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->matplotlib) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->matplotlib) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->matplotlib) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->matplotlib) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.20->matplotlib) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.20->matplotlib) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.20->matplotlib) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.20->matplotlib) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.20->matplotlib) (2024.2.0)
# Collecting backpack
#   Downloading backpack-0.1.tar.gz (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.3/71.3 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: simplejson in /usr/local/lib/python3.11/dist-packages (from backpack) (3.20.1)
# Building wheels for collected packages: backpack
#   Building wheel for backpack (setup.py) ... done
#   Created wheel for backpack: filename=backpack-0.1-cp311-cp311-linux_x86_64.whl size=333809 sha256=06dc973816e303584b8568bdd3f2ec7be32c3b07cbb67247c689e5b143991605
#   Stored in directory: /root/.cache/pip/wheels/8c/9b/39/048c84480638789754d67490f9b2484a0cd2a9be3dd84cf920
# Successfully built backpack
# Installing collected packages: backpack
# Successfully installed backpack-0.1
# Collecting curvlinops-for-pytorch
#   Downloading curvlinops_for_pytorch-2.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting backpack-for-pytorch<2.0.0,>=1.6.0 (from curvlinops-for-pytorch)
#   Downloading backpack_for_pytorch-1.7.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.11/dist-packages (from curvlinops-for-pytorch) (2.6.0+cu124)
# Requirement already satisfied: scipy<2.0.0,>=1.7.1 in /usr/local/lib/python3.11/dist-packages (from curvlinops-for-pytorch) (1.15.2)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.11/dist-packages (from curvlinops-for-pytorch) (1.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.61.0 in /usr/local/lib/python3.11/dist-packages (from curvlinops-for-pytorch) (4.67.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from curvlinops-for-pytorch) (0.8.1)
# Collecting einconv (from curvlinops-for-pytorch)
#   Downloading einconv-0.1.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: torchvision>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from backpack-for-pytorch<2.0.0,>=1.6.0->curvlinops-for-pytorch) (0.21.0+cu124)
# Collecting unfoldNd<1.0.0,>=0.2.0 (from backpack-for-pytorch<2.0.0,>=1.6.0->curvlinops-for-pytorch)
#   Downloading unfoldNd-0.2.3-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.0.0->curvlinops-for-pytorch) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.0.0->curvlinops-for-pytorch) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.0.0->curvlinops-for-pytorch) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.0.0->curvlinops-for-pytorch) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.0.0->curvlinops-for-pytorch) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.0.0->curvlinops-for-pytorch) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->curvlinops-for-pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0->curvlinops-for-pytorch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.7.0->backpack-for-pytorch<2.0.0,>=1.6.0->curvlinops-for-pytorch) (11.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from unfoldNd<1.0.0,>=0.2.0->backpack-for-pytorch<2.0.0,>=1.6.0->curvlinops-for-pytorch) (25.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0->curvlinops-for-pytorch) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.0.0->curvlinops-for-pytorch) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.0.0->curvlinops-for-pytorch) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.0.0->curvlinops-for-pytorch) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.0.0->curvlinops-for-pytorch) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.0.0->curvlinops-for-pytorch) (2024.2.0)
# Downloading curvlinops_for_pytorch-2.0.1-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.4/67.4 kB 2.4 MB/s eta 0:00:00
# Downloading backpack_for_pytorch-1.7.1-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.6/196.6 kB 7.4 MB/s eta 0:00:00
# Downloading einconv-0.1.0-py3-none-any.whl (27 kB)
# Downloading unfoldNd-0.2.3-py3-none-any.whl (16 kB)
# Installing collected packages: einconv, unfoldNd, backpack-for-pytorch, curvlinops-for-pytorch
# Successfully installed backpack-for-pytorch-1.7.1 curvlinops-for-pytorch-2.0.1 einconv-0.1.0 unfoldNd-0.2.3
# Requirement already satisfied: backpack-for-pytorch in /usr/local/lib/python3.11/dist-packages (1.7.1)
# Requirement already satisfied: torch>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from backpack-for-pytorch) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from backpack-for-pytorch) (0.21.0+cu124)
# Requirement already satisfied: einops<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from backpack-for-pytorch) (0.8.1)
# Requirement already satisfied: unfoldNd<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from backpack-for-pytorch) (0.2.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.0->backpack-for-pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.2.0->backpack-for-pytorch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.7.0->backpack-for-pytorch) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.7.0->backpack-for-pytorch) (11.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from unfoldNd<1.0.0,>=0.2.0->backpack-for-pytorch) (25.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.2.0->backpack-for-pytorch) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.7.0->backpack-for-pytorch) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.7.0->backpack-for-pytorch) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.7.0->backpack-for-pytorch) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.7.0->backpack-for-pytorch) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.7.0->backpack-for-pytorch) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.7.0->backpack-for-pytorch) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.7.0->backpack-for-pytorch) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.7.0->backpack-for-pytorch) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision>=0.7.0->backpack-for-pytorch) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision>=0.7.0->backpack-for-pytorch) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision>=0.7.0->backpack-for-pytorch) (2024.2.0)
# Collecting asdfghjkl
#   Downloading asdfghjkl-0.1a5-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from asdfghjkl) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from asdfghjkl) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->asdfghjkl) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->asdfghjkl) (1.3.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->asdfghjkl) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->asdfghjkl) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->asdfghjkl) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->asdfghjkl) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->asdfghjkl) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->asdfghjkl) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->asdfghjkl) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->asdfghjkl) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->asdfghjkl) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->asdfghjkl) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->asdfghjkl) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->asdfghjkl) (2024.2.0)
# Downloading asdfghjkl-0.1a5-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.6/89.6 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: asdfghjkl
# Successfully installed asdfghjkl-0.1a5
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->pandas) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->pandas) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.2->pandas) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.23.2->pandas) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.23.2->pandas) (2024.2.0)
# Collecting git+https://****@github.com/wiseodd/asdl@asdfghjkl
#   Cloning https://****@github.com/wiseodd/asdl (to revision asdfghjkl) to /tmp/pip-req-build-q6onzxp3
#   Running command git clone --filter=blob:none --quiet 'https://****@github.com/wiseodd/asdl' /tmp/pip-req-build-q6onzxp3
#   Running command git checkout -b asdfghjkl --track origin/asdfghjkl
#   Switched to a new branch 'asdfghjkl'
#   Branch 'asdfghjkl' set up to track remote branch 'asdfghjkl' from 'origin'.
#   Resolved https://****@github.com/wiseodd/asdl to commit 9c7640f8a870e82d5b439e6da59d753b207003b0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from asdfghjkl-old==0.1a2) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->asdfghjkl-old==0.1a2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.7.0->asdfghjkl-old==0.1a2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.7.0->asdfghjkl-old==0.1a2) (3.0.2)
# Building wheels for collected packages: asdfghjkl-old
#   Building wheel for asdfghjkl-old (pyproject.toml) ... done
#   Created wheel for asdfghjkl-old: filename=asdfghjkl_old-0.1a2-py3-none-any.whl size=38302 sha256=e0e568cdf60a1b5d9dd9ddbfdaecf99cbada1118488f9ab2c44a0032b1ea2351
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w247i8jw/wheels/b0/9c/9e/1544cb8a45272c4f577ec8043a99a019e3f76e8351a28d5dcf
# Successfully built asdfghjkl-old
# Installing collected packages: asdfghjkl-old
# Successfully installed asdfghjkl-old-0.1a2

# %%
# Copy everything into a writable path
# !cp -r /kaggle/input/laplace-project1/laplace-project1 /kaggle/working/laplace-project1

# Prepare folder for torchvision to download datasets if needed
import os
os.makedirs("/kaggle/working/data", exist_ok=True)

# Set up imports and root path
from pathlib import Path
import sys
project_root = Path("/kaggle/working/laplace-project1")
sys.path.append(str(project_root / "hyperparams"))   # for models
sys.path.append(str(project_root))                   # for laplace/

# Set device
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("Project root:", project_root)
print("Using device:", device)
# Out:
# Project root: /kaggle/working/laplace-project1
# Using device: cuda

# %%
import torch.nn.functional as F
import random
import pandas as pd
from torchvision import datasets, transforms
from torchvision.transforms import functional as TF
from torch.utils.data import DataLoader, random_split
from laplace.laplace import Laplace
from models.lenet.lenet5 import LeNet5
from models.wideresnet.wideresnet import WideResNet
from models.mlp.mlp import MLP
from models.widelenet.widelenet import WideLeNet
from models.resnet.resnet18 import ResNet18

seeds = [0, 42, 123]

# Instantiate and load models
def load_widelenet_models(seeds):
    models = []
    for seed in seeds:
        model = WideLeNet()
        pth = f"{project_root}/hyperparams/models/widelenet/pretrained/widenet_seed{seed}.pth"
        model.load_state_dict(torch.load(pth, map_location=device))
        model.to(device).eval()
        models.append(model)
    return models

def load_resnet_models(seeds):
    models = []
    for seed in seeds:
        model = ResNet18()
        pth = f"{project_root}/hyperparams/models/resnet/pretrained/resnet18_mnist_seed{seed}.pth"
        model.load_state_dict(torch.load(pth, map_location=device))
        model.to(device).eval()
        models.append(model)
    return models

widelenet_models = load_widelenet_models(seeds)
resnet_models = load_resnet_models(seeds)

#check shape
x_dummy = torch.randn(1, 1, 32, 32).to(device)  # for MNIST
print("WideLenet output shape:", widelenet_models[0](x_dummy).shape)
print("Resnet output shape:", resnet_models[0](x_dummy).shape)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# WideLenet output shape: torch.Size([1, 10])
# Resnet output shape: torch.Size([1, 10])

# %%
class FixedRotation:
    def __init__(self, angle):
        self.angle = angle

    def __call__(self, x):
        x = TF.rotate(x, self.angle)  # deterministic
        x = transforms.Resize(32)(x)
        x = transforms.ToTensor()(x)
        x = transforms.Normalize((0.1307,), (0.3081,))(x)
        return x

# %%
transform = transforms.Compose([
    transforms.Resize(32),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

os.makedirs("/kaggle/working/data", exist_ok=True)
# ID - MNIST
mnist_train = datasets.MNIST(root="/kaggle/working/data", train=True, download=True, transform=transform)
mnist_train_loader = DataLoader(mnist_train, batch_size=128, shuffle=False)

mnist_test = datasets.MNIST(root="/kaggle/working/data", train=False, download=True, transform=transform)
mnist_test_loader = DataLoader(mnist_test, batch_size=128, shuffle=False)

# OOD - Fashion MNIST
fashionmnist_test  = datasets.FashionMNIST(root="/kaggle/working/data", train=False, download=True, transform=transform)
fashionmnist_loader = DataLoader(fashionmnist_test, batch_size=128, shuffle=False)

# OOD - RMNIST
rotation_angles = [15, 45, 80, 170]
rotated_loaders = {}

for angle in rotation_angles:
    transform = FixedRotation(angle)
    ds = datasets.MNIST(root="/kaggle/working/data", train=False, download=True, transform=transform)
    rotated_loaders[angle] = DataLoader(ds, batch_size=128, shuffle=False)
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 6.07MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 160kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.52MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.65MB/s]
# 100%|██████████| 26.4M/26.4M [00:03<00:00, 8.54MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 139kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 2.51MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 14.5MB/s]

# %%
# Metrics: ECE and NLL
def compute_ece(probs, labels, n_bins=15):
    confidences, preds = probs.max(1)
    accuracies = preds.eq(labels)
    bins = torch.linspace(0, 1, n_bins + 1, device=probs.device)
    ece = torch.tensor(0., device=probs.device)
    for i in range(n_bins):
        mask = (confidences > bins[i]) & (confidences <= bins[i+1])
        if mask.any():
            ece += mask.float().mean() * (accuracies[mask].float().mean() - confidences[mask].mean()).abs()
    return ece.item()

def compute_nll(probs: torch.Tensor, labels: torch.Tensor) -> float:
    """
    Computes the Negative Log-Likelihood (NLL) given class probabilities and ground-truth labels.
    Assumes `probs` is of shape [batch_size, num_classes] with valid probabilities (summing to 1).
    """
    log_probs = torch.log(probs + 1e-12)  # prevent log(0)
    nll = -log_probs[torch.arange(labels.size(0), device=labels.device), labels]
    return nll.mean().item()

# %%
'''
from itertools import product

# 1. Common hyperparameter values 
prior_precisions   = [1e-6, 1e-2, 1.0, 100.0]
temperatures       = [0.1, 1.0, 2.0]
# For last‐layer non‐GP: use diag/kron/full
hess_structs_main  = ['diag', 'kron', 'full']
# For functional‐GP: only 'gp'
hess_structs_gp    = ['gp']

# 2. Additional options for each pred_type
# 'nn' uses MC sampling
n_samples_nn       = [32, 128, 512]

# 'glm' uses analytic mean/variance plus link‐approx
link_options_glm   = ['probit', 'bridge']
joint_options      = [False, True]
diag_out_options   = [False, True]
# I'll set n_samples=1 for analytic mode

# 'gp' (FunctionalLLLaplace) requires an 'n_subset' choice
n_subset_options   = [256, 512, 1024]
# GP also supports link_approx ∈ {'probit','bridge'} and joint/diagonal_output
# and can do MC‐sampling if n_samples>1 (we’ll leave n_samples=1 here for the analytic predictive)

# 3) Build the hyperparameter grid
hp_grid = []

# pred_type = 'nn'
for pp, temp, hess, n_samp in product(
    prior_precisions,
    temperatures,
    hess_structs_main,
    n_samples_nn
):
    hp_grid.append({
        'prior_precision':   pp,
        'temperature':       temp,
        'hessian_structure': hess,         # one of 'diag','kron','full'
        'pred_type':         'nn',
        'n_samples':         n_samp,       # Monte Carlo draws
        'link_approx':       'mc',         # forced for 'nn'
        'joint':             None,         # ignored for 'nn'
        'diagonal_output':   None,         # ignored for 'nn'
        'subset_of_weights': 'last_layer'
    })

# pred_type = 'glm'
for pp, temp, hess, link, joint_flag, diag_out in product(
    prior_precisions,
    temperatures,
    hess_structs_main,
    link_options_glm,
    joint_options,
    diag_out_options
):
    hp_grid.append({
        'prior_precision':   pp,
        'temperature':       temp,
        'hessian_structure': hess,         # one of 'diag','kron','full'
        'pred_type':         'glm',
        'n_samples':         1,            # analytic GLM; set >1 if you want MC‐samples
        'link_approx':       link,         # 'probit' or 'bridge'
        'joint':             joint_flag,   # whether to compute full C×C covariance
        'diagonal_output':   diag_out,     # whether to return only diag of functional‐cov
        'subset_of_weights': 'last_layer'
    })

# pred_type = 'gp'
for pp, temp, n_sub, link, joint_flag, diag_out in product(
    prior_precisions,
    temperatures,
    n_subset_options,
    link_options_glm,   # GP predictive can also choose 'probit' or 'bridge'
    joint_options,
    diag_out_options
):
    hp_grid.append({
        'prior_precision':   pp,
        'temperature':       temp,
        'hessian_structure': 'gp',         # triggers FunctionalLLLaplace
        'pred_type':         'gp',
        'n_subset':          n_sub,        # # of points to build the GP covariance
        'n_samples':         1,            # analytic GP; set >1 if you want MC‐samples
        'link_approx':       link,         # 'probit' or 'bridge'
        'joint':             joint_flag,   # full functional‐covariance if True
        'diagonal_output':   diag_out,     # use only diagonal of functional‐cov if True
        'subset_of_weights': 'last_layer'
    })

print(f"Total valid configurations: {len(hp_grid)}")
'''

# from itertools import product

# # Common hyperparameter values
# prior_precisions  = [1e-6, 1e-2, 1.0, 10, 100.0]
# temperatures      = [0.5, 1.0]
# # For last‐layer (‘subset_of_weights=last_layer’), we only keep ‘diag’ and ‘kron’
# hess_structs_main = ['diag', 'kron']
# 
# # 2. GLM link‐approx options
# link_options_glm = ['probit', 'bridge']
# diag_out_options = [False, True]
# # We only keep joint=False for simplicity (no full output covariance)
# joint_options = [False]
# 
# # 3. Build the shrunken hyperparameter grid:
# #    (no “nn+MC sampling” block)
# hp_grid = []
# for pp, temp, hess, link, diag_out, joint in product(
#         prior_precisions,
#         temperatures,
#         hess_structs_main,
#         link_options_glm,
#         diag_out_options,
#         joint_options
#     ):
#     hp_grid.append({
#         'prior_precision':   pp,
#         'temperature':       temp,
#         'hessian_structure': hess,         # 'diag' or 'kron'
#         'pred_type':         'glm',        # always analytic GLM for last‐layer
#         'n_samples':         1,            # analytic mode
#         'link_approx':       link,         # 'probit' or 'bridge'
#         'joint':             joint,        # False
#         'diagonal_output':   diag_out,     # True/False
#         'subset_of_weights': 'last_layer'
#     })

# Hyperparameter grid: prior_precision & hessian_structure, random sample ~25 combos
prior_precisions = [1e-6, 1e-4, 1e-2, 1.0, 10.0, 100.0]
temperatures = [0.1, 0.5, 1.0]
hessian_structs  = ['diag', 'kron']
link_approxs = ['probit', 'bridge']

all_configs = [
    {
      'prior_precision': pp,
      'hessian_structure': hess,
      'temperature': T,
      'link_approx': L,
      'subset_of_weights': 'last_layer'
    }
    for pp in prior_precisions
    for hess in hessian_structs
    for T in temperatures
    for L in link_approxs
]

hp_grid = all_configs
print(f"Sampling {len(hp_grid)} configurations for sensitivity analysis")
# Out:
# Sampling 72 configurations for sensitivity analysis

# %%
import time

# Run experiments (full config sweep: pp, hess, temp, link) with Accuracy & Brier
models_dict = {
    "widelenet": widelenet_models,
    "resnet18": resnet_models
}

output_dir = Path("/kaggle/working/laplace_outputs")
output_dir.mkdir(parents=True, exist_ok=True)

results = []
total_runs = len(models_dict) * len(hp_grid) * len(rotation_angles) * len(seeds)
run_idx = 0

start_all = time.time()
for arch, model_list in models_dict.items():
    for config in hp_grid:
        pp    = config['prior_precision']
        hess  = config['hessian_structure']
        temp  = config['temperature']
        link  = config['link_approx']

        for base_idx, base in enumerate(model_list, start=1):
            run_idx += 1
            seed = seeds[base_idx-1]
            print(f"[{run_idx}/{total_runs}] arch={arch}, seed={seed}, "
                  f"pp={pp}, hess={hess}, temp={temp}, link={link}")

            # Load & fit once per (arch, seed, config)
            m = type(base)().to(device)
            m.load_state_dict(base.state_dict())
            m.eval()
            la = Laplace(
                m,
                likelihood='classification',
                subset_of_weights='last_layer',
                hessian_structure=hess,
                prior_precision=pp,
                temperature=temp,
                enable_backprop=False
            )
            t0 = time.time()
            la.fit(mnist_train_loader)
            print(f"  Fit done in {time.time() - t0:.1f}s")

            # ID eval
            t0 = time.time()
            probs_id, labels_id = [], []
            with torch.no_grad():
                for X, y in mnist_test_loader:
                    p = la(X.to(device), pred_type='glm', link_approx=link, n_samples=1)
                    probs_id.append(p.cpu()); labels_id.append(y)
            probs_id = torch.cat(probs_id)
            labels_id = torch.cat(labels_id)
            nll_id = compute_nll(probs_id, labels_id)
            ece_id = compute_ece(probs_id, labels_id)
            acc_id = (probs_id.argmax(1) == labels_id).float().mean().item()
            one_hot = F.one_hot(labels_id, num_classes=probs_id.size(-1)).float()
            brier_id = ((probs_id - one_hot)**2).sum(1).mean().item()
            print(f"  ID eval done in {time.time() - t0:.1f}s")

            # OOD eval: rotated MNIST
            for angle in rotation_angles:
                t0 = time.time()
                probs_ood, labels_ood = [], []
                with torch.no_grad():
                    loader = rotated_loaders[angle]
                    for X, y in loader:
                        p = la(X.to(device), pred_type='glm', link_approx=link, n_samples=1)
                        probs_ood.append(p.cpu()); labels_ood.append(y)
                probs_ood = torch.cat(probs_ood)
                labels_ood = torch.cat(labels_ood)
                nll_ood = compute_nll(probs_ood, labels_ood)
                ece_ood = compute_ece(probs_ood, labels_ood)
                acc_ood = (probs_ood.argmax(1) == labels_ood).float().mean().item()
                one_hot_ood = F.one_hot(labels_ood, num_classes=probs_ood.size(-1)).float()
                brier_ood = ((probs_ood - one_hot_ood)**2).sum(1).mean().item()
                print(f"    OOD {angle}° eval done in {time.time() - t0:.1f}s")

                # Append result row
                results.append({
                    "arch": arch,
                    "seed": seed,
                    "prior_precision": pp,
                    "hessian_structure": hess,
                    "temperature": temp,
                    "link_approx": link,
                    "rotation": angle,
                    "nll_id":    nll_id,
                    "ece_id":    ece_id,
                    "acc_id":    acc_id,
                    "brier_id":  brier_id,
                    "nll_ood":   nll_ood,
                    "ece_ood":   ece_ood,
                    "acc_ood":   acc_ood,
                    "brier_ood": brier_ood
                })

            # Clean up
            del m, la
            torch.cuda.empty_cache()

            # FLUSH partial results
            # Save current results to CSV after each seed finishes
            pd.DataFrame(results).to_csv(output_dir / "sensitivity_results.csv", index=False)
            print(f"  Flushed {len(results)} rows to {output_dir/'sensitivity_results.csv'}")

# Final save
df = pd.DataFrame(results)
df.to_csv(output_dir / "sensitivity_results.csv", index=False)
print(f"Experiment complete in {time.time() - start_all:.1f}s")
print(f"Final results saved to {output_dir/'sensitivity_results.csv'}")
# Out:
# [1/1728] arch=widelenet, seed=0, pp=1e-06, hess=diag, temp=0.1, link=probit
#   Fit done in 12.6s
#   ID eval done in 2.3s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.1s
#   Flushed 4 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [2/1728] arch=widelenet, seed=42, pp=1e-06, hess=diag, temp=0.1, link=probit
#   Fit done in 13.1s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 8 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [3/1728] arch=widelenet, seed=123, pp=1e-06, hess=diag, temp=0.1, link=probit
#   Fit done in 13.0s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 12 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [4/1728] arch=widelenet, seed=0, pp=1e-06, hess=diag, temp=0.1, link=bridge
#   Fit done in 13.5s
#   ID eval done in 2.3s
#     OOD 15° eval done in 3.3s
#     OOD 45° eval done in 3.3s
#     OOD 80° eval done in 3.3s
#     OOD 170° eval done in 3.4s
#   Flushed 16 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [5/1728] arch=widelenet, seed=42, pp=1e-06, hess=diag, temp=0.1, link=bridge
#   Fit done in 13.3s
#   ID eval done in 2.3s
#     OOD 15° eval done in 3.3s
#     OOD 45° eval done in 3.3s
#     OOD 80° eval done in 3.3s
#     OOD 170° eval done in 3.3s
#   Flushed 20 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [6/1728] arch=widelenet, seed=123, pp=1e-06, hess=diag, temp=0.1, link=bridge
#   Fit done in 13.4s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.3s
#     OOD 45° eval done in 3.3s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.3s
#   Flushed 24 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [7/1728] arch=widelenet, seed=0, pp=1e-06, hess=diag, temp=0.5, link=probit
#   Fit done in 13.2s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 28 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [8/1728] arch=widelenet, seed=42, pp=1e-06, hess=diag, temp=0.5, link=probit
#   Fit done in 13.4s
#   ID eval done in 2.4s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.3s
#     OOD 170° eval done in 3.3s
#   Flushed 32 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [9/1728] arch=widelenet, seed=123, pp=1e-06, hess=diag, temp=0.5, link=probit
#   Fit done in 13.3s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.3s
#     OOD 170° eval done in 3.2s
#   Flushed 36 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [10/1728] arch=widelenet, seed=0, pp=1e-06, hess=diag, temp=0.5, link=bridge
#   Fit done in 13.2s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.3s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 40 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [11/1728] arch=widelenet, seed=42, pp=1e-06, hess=diag, temp=0.5, link=bridge
#   Fit done in 13.2s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.3s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 44 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [12/1728] arch=widelenet, seed=123, pp=1e-06, hess=diag, temp=0.5, link=bridge
#   Fit done in 12.9s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.3s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 48 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [13/1728] arch=widelenet, seed=0, pp=1e-06, hess=diag, temp=1.0, link=probit
#   Fit done in 13.0s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.3s
#     OOD 170° eval done in 3.1s
#   Flushed 52 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [14/1728] arch=widelenet, seed=42, pp=1e-06, hess=diag, temp=1.0, link=probit
#   Fit done in 12.8s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.3s
#   Flushed 56 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [15/1728] arch=widelenet, seed=123, pp=1e-06, hess=diag, temp=1.0, link=probit
#   Fit done in 12.7s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.1s
#   Flushed 60 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [16/1728] arch=widelenet, seed=0, pp=1e-06, hess=diag, temp=1.0, link=bridge
#   Fit done in 12.8s
#   ID eval done in 2.3s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.1s
#   Flushed 64 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [17/1728] arch=widelenet, seed=42, pp=1e-06, hess=diag, temp=1.0, link=bridge
#   Fit done in 13.0s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.5s
#     OOD 170° eval done in 3.3s
#   Flushed 68 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [18/1728] arch=widelenet, seed=123, pp=1e-06, hess=diag, temp=1.0, link=bridge
#   Fit done in 13.2s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.4s
#     OOD 80° eval done in 3.3s
#     OOD 170° eval done in 3.3s
#   Flushed 72 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [19/1728] arch=widelenet, seed=0, pp=1e-06, hess=kron, temp=0.1, link=probit
#   Fit done in 23.1s
#   ID eval done in 2.3s
#     OOD 15° eval done in 3.3s
#     OOD 45° eval done in 3.3s
#     OOD 80° eval done in 3.3s
#     OOD 170° eval done in 3.2s
#   Flushed 76 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [20/1728] arch=widelenet, seed=42, pp=1e-06, hess=kron, temp=0.1, link=probit
#   Fit done in 23.0s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.3s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.3s
#   Flushed 80 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [21/1728] arch=widelenet, seed=123, pp=1e-06, hess=kron, temp=0.1, link=probit
#   Fit done in 23.2s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.3s
#     OOD 170° eval done in 3.2s
#   Flushed 84 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [22/1728] arch=widelenet, seed=0, pp=1e-06, hess=kron, temp=0.1, link=bridge
#   Fit done in 22.7s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.3s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 88 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [23/1728] arch=widelenet, seed=42, pp=1e-06, hess=kron, temp=0.1, link=bridge
#   Fit done in 22.6s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 92 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [24/1728] arch=widelenet, seed=123, pp=1e-06, hess=kron, temp=0.1, link=bridge
#   Fit done in 22.5s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 96 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [25/1728] arch=widelenet, seed=0, pp=1e-06, hess=kron, temp=0.5, link=probit
#   Fit done in 22.5s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 100 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [26/1728] arch=widelenet, seed=42, pp=1e-06, hess=kron, temp=0.5, link=probit
#   Fit done in 22.6s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 104 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [27/1728] arch=widelenet, seed=123, pp=1e-06, hess=kron, temp=0.5, link=probit
#   Fit done in 22.6s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.3s
#     OOD 80° eval done in 3.3s
#     OOD 170° eval done in 3.2s
#   Flushed 108 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [28/1728] arch=widelenet, seed=0, pp=1e-06, hess=kron, temp=0.5, link=bridge
#   Fit done in 22.5s
#   ID eval done in 2.3s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.3s
#     OOD 170° eval done in 3.2s
#   Flushed 112 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [29/1728] arch=widelenet, seed=42, pp=1e-06, hess=kron, temp=0.5, link=bridge
#   Fit done in 22.7s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.3s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.3s
#   Flushed 116 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [30/1728] arch=widelenet, seed=123, pp=1e-06, hess=kron, temp=0.5, link=bridge
#   Fit done in 22.6s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.3s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 120 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [31/1728] arch=widelenet, seed=0, pp=1e-06, hess=kron, temp=1.0, link=probit
#   Fit done in 22.6s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.3s
#   Flushed 124 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [32/1728] arch=widelenet, seed=42, pp=1e-06, hess=kron, temp=1.0, link=probit
#   Fit done in 22.5s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 128 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [33/1728] arch=widelenet, seed=123, pp=1e-06, hess=kron, temp=1.0, link=probit
#   Fit done in 22.3s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 132 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [34/1728] arch=widelenet, seed=0, pp=1e-06, hess=kron, temp=1.0, link=bridge
#   Fit done in 22.5s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.1s
#   Flushed 136 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [35/1728] arch=widelenet, seed=42, pp=1e-06, hess=kron, temp=1.0, link=bridge
#   Fit done in 22.9s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.1s
#   Flushed 140 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [36/1728] arch=widelenet, seed=123, pp=1e-06, hess=kron, temp=1.0, link=bridge
#   Fit done in 22.5s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 144 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [37/1728] arch=widelenet, seed=0, pp=0.0001, hess=diag, temp=0.1, link=probit
#   Fit done in 12.7s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 148 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [38/1728] arch=widelenet, seed=42, pp=0.0001, hess=diag, temp=0.1, link=probit
#   Fit done in 12.6s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 152 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [39/1728] arch=widelenet, seed=123, pp=0.0001, hess=diag, temp=0.1, link=probit
#   Fit done in 12.7s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 156 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [40/1728] arch=widelenet, seed=0, pp=0.0001, hess=diag, temp=0.1, link=bridge
#   Fit done in 12.6s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.3s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 160 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [41/1728] arch=widelenet, seed=42, pp=0.0001, hess=diag, temp=0.1, link=bridge
#   Fit done in 12.7s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.1s
#   Flushed 164 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [42/1728] arch=widelenet, seed=123, pp=0.0001, hess=diag, temp=0.1, link=bridge
#   Fit done in 12.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 168 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [43/1728] arch=widelenet, seed=0, pp=0.0001, hess=diag, temp=0.5, link=probit
#   Fit done in 12.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 172 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [44/1728] arch=widelenet, seed=42, pp=0.0001, hess=diag, temp=0.5, link=probit
#   Fit done in 12.7s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.1s
#   Flushed 176 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [45/1728] arch=widelenet, seed=123, pp=0.0001, hess=diag, temp=0.5, link=probit
#   Fit done in 12.6s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 180 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [46/1728] arch=widelenet, seed=0, pp=0.0001, hess=diag, temp=0.5, link=bridge
#   Fit done in 12.9s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 184 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [47/1728] arch=widelenet, seed=42, pp=0.0001, hess=diag, temp=0.5, link=bridge
#   Fit done in 12.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 188 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [48/1728] arch=widelenet, seed=123, pp=0.0001, hess=diag, temp=0.5, link=bridge
#   Fit done in 12.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 192 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [49/1728] arch=widelenet, seed=0, pp=0.0001, hess=diag, temp=1.0, link=probit
#   Fit done in 12.6s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.1s
#   Flushed 196 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [50/1728] arch=widelenet, seed=42, pp=0.0001, hess=diag, temp=1.0, link=probit
#   Fit done in 12.6s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 200 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [51/1728] arch=widelenet, seed=123, pp=0.0001, hess=diag, temp=1.0, link=probit
#   Fit done in 12.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 204 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [52/1728] arch=widelenet, seed=0, pp=0.0001, hess=diag, temp=1.0, link=bridge
#   Fit done in 12.6s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 208 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [53/1728] arch=widelenet, seed=42, pp=0.0001, hess=diag, temp=1.0, link=bridge
#   Fit done in 12.8s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 212 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [54/1728] arch=widelenet, seed=123, pp=0.0001, hess=diag, temp=1.0, link=bridge
#   Fit done in 12.6s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 216 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [55/1728] arch=widelenet, seed=0, pp=0.0001, hess=kron, temp=0.1, link=probit
#   Fit done in 22.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 220 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [56/1728] arch=widelenet, seed=42, pp=0.0001, hess=kron, temp=0.1, link=probit
#   Fit done in 22.2s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 224 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [57/1728] arch=widelenet, seed=123, pp=0.0001, hess=kron, temp=0.1, link=probit
#   Fit done in 22.4s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 228 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [58/1728] arch=widelenet, seed=0, pp=0.0001, hess=kron, temp=0.1, link=bridge
#   Fit done in 22.1s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.4s
#   Flushed 232 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [59/1728] arch=widelenet, seed=42, pp=0.0001, hess=kron, temp=0.1, link=bridge
#   Fit done in 23.0s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.4s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.4s
#   Flushed 236 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [60/1728] arch=widelenet, seed=123, pp=0.0001, hess=kron, temp=0.1, link=bridge
#   Fit done in 22.4s
#   ID eval done in 2.4s
#     OOD 15° eval done in 3.3s
#     OOD 45° eval done in 3.3s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 240 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [61/1728] arch=widelenet, seed=0, pp=0.0001, hess=kron, temp=0.5, link=probit
#   Fit done in 22.4s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.1s
#   Flushed 244 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [62/1728] arch=widelenet, seed=42, pp=0.0001, hess=kron, temp=0.5, link=probit
#   Fit done in 22.3s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 248 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [63/1728] arch=widelenet, seed=123, pp=0.0001, hess=kron, temp=0.5, link=probit
#   Fit done in 22.1s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 252 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [64/1728] arch=widelenet, seed=0, pp=0.0001, hess=kron, temp=0.5, link=bridge
#   Fit done in 22.1s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.1s
#   Flushed 256 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [65/1728] arch=widelenet, seed=42, pp=0.0001, hess=kron, temp=0.5, link=bridge
#   Fit done in 21.9s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 260 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [66/1728] arch=widelenet, seed=123, pp=0.0001, hess=kron, temp=0.5, link=bridge
#   Fit done in 22.2s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 264 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [67/1728] arch=widelenet, seed=0, pp=0.0001, hess=kron, temp=1.0, link=probit
#   Fit done in 22.0s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 268 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [68/1728] arch=widelenet, seed=42, pp=0.0001, hess=kron, temp=1.0, link=probit
#   Fit done in 22.3s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 272 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [69/1728] arch=widelenet, seed=123, pp=0.0001, hess=kron, temp=1.0, link=probit
#   Fit done in 22.2s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 276 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [70/1728] arch=widelenet, seed=0, pp=0.0001, hess=kron, temp=1.0, link=bridge
#   Fit done in 21.9s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 280 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [71/1728] arch=widelenet, seed=42, pp=0.0001, hess=kron, temp=1.0, link=bridge
#   Fit done in 22.1s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 284 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [72/1728] arch=widelenet, seed=123, pp=0.0001, hess=kron, temp=1.0, link=bridge
#   Fit done in 21.9s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.1s
#   Flushed 288 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [73/1728] arch=widelenet, seed=0, pp=0.01, hess=diag, temp=0.1, link=probit
#   Fit done in 12.4s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 292 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [74/1728] arch=widelenet, seed=42, pp=0.01, hess=diag, temp=0.1, link=probit
#   Fit done in 12.6s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 296 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [75/1728] arch=widelenet, seed=123, pp=0.01, hess=diag, temp=0.1, link=probit
#   Fit done in 12.3s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.0s
#   Flushed 300 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [76/1728] arch=widelenet, seed=0, pp=0.01, hess=diag, temp=0.1, link=bridge
#   Fit done in 12.4s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 304 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [77/1728] arch=widelenet, seed=42, pp=0.01, hess=diag, temp=0.1, link=bridge
#   Fit done in 12.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 308 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [78/1728] arch=widelenet, seed=123, pp=0.01, hess=diag, temp=0.1, link=bridge
#   Fit done in 12.4s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 312 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [79/1728] arch=widelenet, seed=0, pp=0.01, hess=diag, temp=0.5, link=probit
#   Fit done in 12.4s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 316 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [80/1728] arch=widelenet, seed=42, pp=0.01, hess=diag, temp=0.5, link=probit
#   Fit done in 12.4s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.0s
#   Flushed 320 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [81/1728] arch=widelenet, seed=123, pp=0.01, hess=diag, temp=0.5, link=probit
#   Fit done in 12.4s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.1s
#   Flushed 324 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [82/1728] arch=widelenet, seed=0, pp=0.01, hess=diag, temp=0.5, link=bridge
#   Fit done in 12.4s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.0s
#   Flushed 328 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [83/1728] arch=widelenet, seed=42, pp=0.01, hess=diag, temp=0.5, link=bridge
#   Fit done in 12.4s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.0s
#   Flushed 332 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [84/1728] arch=widelenet, seed=123, pp=0.01, hess=diag, temp=0.5, link=bridge
#   Fit done in 12.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.1s
#   Flushed 336 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [85/1728] arch=widelenet, seed=0, pp=0.01, hess=diag, temp=1.0, link=probit
#   Fit done in 12.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 340 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [86/1728] arch=widelenet, seed=42, pp=0.01, hess=diag, temp=1.0, link=probit
#   Fit done in 12.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 344 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [87/1728] arch=widelenet, seed=123, pp=0.01, hess=diag, temp=1.0, link=probit
#   Fit done in 12.4s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.1s
#   Flushed 348 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [88/1728] arch=widelenet, seed=0, pp=0.01, hess=diag, temp=1.0, link=bridge
#   Fit done in 12.4s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 352 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [89/1728] arch=widelenet, seed=42, pp=0.01, hess=diag, temp=1.0, link=bridge
#   Fit done in 12.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 356 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [90/1728] arch=widelenet, seed=123, pp=0.01, hess=diag, temp=1.0, link=bridge
#   Fit done in 12.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.1s
#   Flushed 360 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [91/1728] arch=widelenet, seed=0, pp=0.01, hess=kron, temp=0.1, link=probit
#   Fit done in 22.0s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 364 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [92/1728] arch=widelenet, seed=42, pp=0.01, hess=kron, temp=0.1, link=probit
#   Fit done in 21.9s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 368 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [93/1728] arch=widelenet, seed=123, pp=0.01, hess=kron, temp=0.1, link=probit
#   Fit done in 22.0s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 372 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [94/1728] arch=widelenet, seed=0, pp=0.01, hess=kron, temp=0.1, link=bridge
#   Fit done in 21.8s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 376 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [95/1728] arch=widelenet, seed=42, pp=0.01, hess=kron, temp=0.1, link=bridge
#   Fit done in 21.7s
#   ID eval done in 2.4s
#     OOD 15° eval done in 3.3s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 380 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [96/1728] arch=widelenet, seed=123, pp=0.01, hess=kron, temp=0.1, link=bridge
#   Fit done in 22.7s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.4s
#     OOD 45° eval done in 3.3s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 384 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [97/1728] arch=widelenet, seed=0, pp=0.01, hess=kron, temp=0.5, link=probit
#   Fit done in 22.3s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 388 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [98/1728] arch=widelenet, seed=42, pp=0.01, hess=kron, temp=0.5, link=probit
#   Fit done in 22.2s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.1s
#   Flushed 392 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [99/1728] arch=widelenet, seed=123, pp=0.01, hess=kron, temp=0.5, link=probit
#   Fit done in 22.4s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 396 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [100/1728] arch=widelenet, seed=0, pp=0.01, hess=kron, temp=0.5, link=bridge
#   Fit done in 21.8s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 400 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [101/1728] arch=widelenet, seed=42, pp=0.01, hess=kron, temp=0.5, link=bridge
#   Fit done in 21.8s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 404 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [102/1728] arch=widelenet, seed=123, pp=0.01, hess=kron, temp=0.5, link=bridge
#   Fit done in 21.7s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 408 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [103/1728] arch=widelenet, seed=0, pp=0.01, hess=kron, temp=1.0, link=probit
#   Fit done in 21.8s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 412 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [104/1728] arch=widelenet, seed=42, pp=0.01, hess=kron, temp=1.0, link=probit
#   Fit done in 22.1s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 416 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [105/1728] arch=widelenet, seed=123, pp=0.01, hess=kron, temp=1.0, link=probit
#   Fit done in 22.0s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 420 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [106/1728] arch=widelenet, seed=0, pp=0.01, hess=kron, temp=1.0, link=bridge
#   Fit done in 21.8s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 424 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [107/1728] arch=widelenet, seed=42, pp=0.01, hess=kron, temp=1.0, link=bridge
#   Fit done in 21.7s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 428 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [108/1728] arch=widelenet, seed=123, pp=0.01, hess=kron, temp=1.0, link=bridge
#   Fit done in 21.8s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.1s
#   Flushed 432 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [109/1728] arch=widelenet, seed=0, pp=1.0, hess=diag, temp=0.1, link=probit
#   Fit done in 12.3s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 436 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [110/1728] arch=widelenet, seed=42, pp=1.0, hess=diag, temp=0.1, link=probit
#   Fit done in 12.3s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.1s
#   Flushed 440 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [111/1728] arch=widelenet, seed=123, pp=1.0, hess=diag, temp=0.1, link=probit
#   Fit done in 12.3s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 444 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [112/1728] arch=widelenet, seed=0, pp=1.0, hess=diag, temp=0.1, link=bridge
#   Fit done in 12.4s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 448 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [113/1728] arch=widelenet, seed=42, pp=1.0, hess=diag, temp=0.1, link=bridge
#   Fit done in 12.3s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 452 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [114/1728] arch=widelenet, seed=123, pp=1.0, hess=diag, temp=0.1, link=bridge
#   Fit done in 12.4s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.1s
#   Flushed 456 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [115/1728] arch=widelenet, seed=0, pp=1.0, hess=diag, temp=0.5, link=probit
#   Fit done in 12.3s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 460 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [116/1728] arch=widelenet, seed=42, pp=1.0, hess=diag, temp=0.5, link=probit
#   Fit done in 12.2s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.0s
#   Flushed 464 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [117/1728] arch=widelenet, seed=123, pp=1.0, hess=diag, temp=0.5, link=probit
#   Fit done in 12.3s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 468 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [118/1728] arch=widelenet, seed=0, pp=1.0, hess=diag, temp=0.5, link=bridge
#   Fit done in 12.4s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 472 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [119/1728] arch=widelenet, seed=42, pp=1.0, hess=diag, temp=0.5, link=bridge
#   Fit done in 12.3s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.1s
#   Flushed 476 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [120/1728] arch=widelenet, seed=123, pp=1.0, hess=diag, temp=0.5, link=bridge
#   Fit done in 12.3s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 480 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [121/1728] arch=widelenet, seed=0, pp=1.0, hess=diag, temp=1.0, link=probit
#   Fit done in 12.3s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 484 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [122/1728] arch=widelenet, seed=42, pp=1.0, hess=diag, temp=1.0, link=probit
#   Fit done in 12.3s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.2s
#   Flushed 488 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [123/1728] arch=widelenet, seed=123, pp=1.0, hess=diag, temp=1.0, link=probit
#   Fit done in 12.3s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 492 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [124/1728] arch=widelenet, seed=0, pp=1.0, hess=diag, temp=1.0, link=bridge
#   Fit done in 12.5s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.0s
#   Flushed 496 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [125/1728] arch=widelenet, seed=42, pp=1.0, hess=diag, temp=1.0, link=bridge
#   Fit done in 12.4s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.0s
#   Flushed 500 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [126/1728] arch=widelenet, seed=123, pp=1.0, hess=diag, temp=1.0, link=bridge
#   Fit done in 12.3s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.0s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.0s
#   Flushed 504 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [127/1728] arch=widelenet, seed=0, pp=1.0, hess=kron, temp=0.1, link=probit
#   Fit done in 21.9s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 508 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [128/1728] arch=widelenet, seed=42, pp=1.0, hess=kron, temp=0.1, link=probit
#   Fit done in 21.8s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 512 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [129/1728] arch=widelenet, seed=123, pp=1.0, hess=kron, temp=0.1, link=probit
#   Fit done in 21.8s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 516 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [130/1728] arch=widelenet, seed=0, pp=1.0, hess=kron, temp=0.1, link=bridge
#   Fit done in 21.9s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 520 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [131/1728] arch=widelenet, seed=42, pp=1.0, hess=kron, temp=0.1, link=bridge
#   Fit done in 22.0s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 524 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [132/1728] arch=widelenet, seed=123, pp=1.0, hess=kron, temp=0.1, link=bridge
#   Fit done in 21.9s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 528 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [133/1728] arch=widelenet, seed=0, pp=1.0, hess=kron, temp=0.5, link=probit
#   Fit done in 22.3s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 532 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [134/1728] arch=widelenet, seed=42, pp=1.0, hess=kron, temp=0.5, link=probit
#   Fit done in 22.7s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 536 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [135/1728] arch=widelenet, seed=123, pp=1.0, hess=kron, temp=0.5, link=probit
#   Fit done in 22.1s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 540 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [136/1728] arch=widelenet, seed=0, pp=1.0, hess=kron, temp=0.5, link=bridge
#   Fit done in 22.7s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.3s
#   Flushed 544 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [137/1728] arch=widelenet, seed=42, pp=1.0, hess=kron, temp=0.5, link=bridge
#   Fit done in 22.8s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.3s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 548 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [138/1728] arch=widelenet, seed=123, pp=1.0, hess=kron, temp=0.5, link=bridge
#   Fit done in 22.6s
#   ID eval done in 2.3s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 552 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [139/1728] arch=widelenet, seed=0, pp=1.0, hess=kron, temp=1.0, link=probit
#   Fit done in 22.5s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 556 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [140/1728] arch=widelenet, seed=42, pp=1.0, hess=kron, temp=1.0, link=probit
#   Fit done in 22.1s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 560 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [141/1728] arch=widelenet, seed=123, pp=1.0, hess=kron, temp=1.0, link=probit
#   Fit done in 22.0s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.0s
#     OOD 170° eval done in 3.1s
#   Flushed 564 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [142/1728] arch=widelenet, seed=0, pp=1.0, hess=kron, temp=1.0, link=bridge
#   Fit done in 21.8s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.2s
#   Flushed 568 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [143/1728] arch=widelenet, seed=42, pp=1.0, hess=kron, temp=1.0, link=bridge
#   Fit done in 22.4s
#   ID eval done in 2.2s
#     OOD 15° eval done in 3.2s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 572 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [144/1728] arch=widelenet, seed=123, pp=1.0, hess=kron, temp=1.0, link=bridge
#   Fit done in 22.3s
#   ID eval done in 2.3s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 576 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [145/1728] arch=widelenet, seed=0, pp=10.0, hess=diag, temp=0.1, link=probit
#   Fit done in 12.4s
#   ID eval done in 2.0s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.2s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 580 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [146/1728] arch=widelenet, seed=42, pp=10.0, hess=diag, temp=0.1, link=probit
#   Fit done in 12.6s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.2s
#     OOD 170° eval done in 3.1s
#   Flushed 584 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [147/1728] arch=widelenet, seed=123, pp=10.0, hess=diag, temp=0.1, link=probit
#   Fit done in 12.6s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.0s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 588 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [148/1728] arch=widelenet, seed=0, pp=10.0, hess=diag, temp=0.1, link=bridge
#   Fit done in 13.0s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.2s
#   Flushed 592 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [149/1728] arch=widelenet, seed=42, pp=10.0, hess=diag, temp=0.1, link=bridge
#   Fit done in 12.7s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 596 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [150/1728] arch=widelenet, seed=123, pp=10.0, hess=diag, temp=0.1, link=bridge
#   Fit done in 12.8s
#   ID eval done in 2.1s
#     OOD 15° eval done in 3.1s
#     OOD 45° eval done in 3.1s
#     OOD 80° eval done in 3.1s
#     OOD 170° eval done in 3.1s
#   Flushed 600 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# ...
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.9s
#   Flushed 1532 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [384/1728] arch=resnet18, seed=123, pp=10.0, hess=kron, temp=0.1, link=bridge
#   Fit done in 24.5s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.9s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.8s
#   Flushed 1536 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [385/1728] arch=resnet18, seed=0, pp=10.0, hess=kron, temp=0.5, link=probit
#   Fit done in 24.7s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.7s
#     OOD 45° eval done in 3.7s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.7s
#   Flushed 1540 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [386/1728] arch=resnet18, seed=42, pp=10.0, hess=kron, temp=0.5, link=probit
#   Fit done in 24.6s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.9s
#     OOD 45° eval done in 3.9s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.9s
#   Flushed 1544 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [387/1728] arch=resnet18, seed=123, pp=10.0, hess=kron, temp=0.5, link=probit
#   Fit done in 24.4s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.9s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.9s
#   Flushed 1548 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [388/1728] arch=resnet18, seed=0, pp=10.0, hess=kron, temp=0.5, link=bridge
#   Fit done in 24.7s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.9s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 3.9s
#   Flushed 1552 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [389/1728] arch=resnet18, seed=42, pp=10.0, hess=kron, temp=0.5, link=bridge
#   Fit done in 24.4s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 3.8s
#   Flushed 1556 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [390/1728] arch=resnet18, seed=123, pp=10.0, hess=kron, temp=0.5, link=bridge
#   Fit done in 24.7s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.8s
#   Flushed 1560 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [391/1728] arch=resnet18, seed=0, pp=10.0, hess=kron, temp=1.0, link=probit
#   Fit done in 24.6s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.8s
#   Flushed 1564 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [392/1728] arch=resnet18, seed=42, pp=10.0, hess=kron, temp=1.0, link=probit
#   Fit done in 24.5s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.8s
#   Flushed 1568 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [393/1728] arch=resnet18, seed=123, pp=10.0, hess=kron, temp=1.0, link=probit
#   Fit done in 24.9s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.9s
#   Flushed 1572 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [394/1728] arch=resnet18, seed=0, pp=10.0, hess=kron, temp=1.0, link=bridge
#   Fit done in 24.7s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.9s
#     OOD 45° eval done in 3.9s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 3.9s
#   Flushed 1576 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [395/1728] arch=resnet18, seed=42, pp=10.0, hess=kron, temp=1.0, link=bridge
#   Fit done in 24.9s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.9s
#     OOD 45° eval done in 3.9s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 3.9s
#   Flushed 1580 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [396/1728] arch=resnet18, seed=123, pp=10.0, hess=kron, temp=1.0, link=bridge
#   Fit done in 24.7s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.9s
#     OOD 80° eval done in 4.0s
#     OOD 170° eval done in 3.9s
#   Flushed 1584 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [397/1728] arch=resnet18, seed=0, pp=100.0, hess=diag, temp=0.1, link=probit
#   Fit done in 13.6s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.7s
#     OOD 170° eval done in 3.7s
#   Flushed 1588 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [398/1728] arch=resnet18, seed=42, pp=100.0, hess=diag, temp=0.1, link=probit
#   Fit done in 13.5s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.7s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.7s
#     OOD 170° eval done in 3.7s
#   Flushed 1592 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [399/1728] arch=resnet18, seed=123, pp=100.0, hess=diag, temp=0.1, link=probit
#   Fit done in 13.5s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.7s
#   Flushed 1596 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [400/1728] arch=resnet18, seed=0, pp=100.0, hess=diag, temp=0.1, link=bridge
#   Fit done in 13.6s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.7s
#   Flushed 1600 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [401/1728] arch=resnet18, seed=42, pp=100.0, hess=diag, temp=0.1, link=bridge
#   Fit done in 13.5s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.7s
#   Flushed 1604 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [402/1728] arch=resnet18, seed=123, pp=100.0, hess=diag, temp=0.1, link=bridge
#   Fit done in 13.4s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.8s
#   Flushed 1608 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [403/1728] arch=resnet18, seed=0, pp=100.0, hess=diag, temp=0.5, link=probit
#   Fit done in 13.5s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.6s
#   Flushed 1612 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [404/1728] arch=resnet18, seed=42, pp=100.0, hess=diag, temp=0.5, link=probit
#   Fit done in 13.4s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.6s
#   Flushed 1616 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [405/1728] arch=resnet18, seed=123, pp=100.0, hess=diag, temp=0.5, link=probit
#   Fit done in 13.5s
#   ID eval done in 2.6s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.6s
#   Flushed 1620 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [406/1728] arch=resnet18, seed=0, pp=100.0, hess=diag, temp=0.5, link=bridge
#   Fit done in 13.5s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.6s
#   Flushed 1624 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [407/1728] arch=resnet18, seed=42, pp=100.0, hess=diag, temp=0.5, link=bridge
#   Fit done in 13.4s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.6s
#   Flushed 1628 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [408/1728] arch=resnet18, seed=123, pp=100.0, hess=diag, temp=0.5, link=bridge
#   Fit done in 13.4s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.7s
#   Flushed 1632 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [409/1728] arch=resnet18, seed=0, pp=100.0, hess=diag, temp=1.0, link=probit
#   Fit done in 13.4s
#   ID eval done in 2.6s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.6s
#   Flushed 1636 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [410/1728] arch=resnet18, seed=42, pp=100.0, hess=diag, temp=1.0, link=probit
#   Fit done in 13.4s
#   ID eval done in 2.6s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.7s
#     OOD 170° eval done in 3.7s
#   Flushed 1640 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [411/1728] arch=resnet18, seed=123, pp=100.0, hess=diag, temp=1.0, link=probit
#   Fit done in 13.4s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.6s
#   Flushed 1644 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [412/1728] arch=resnet18, seed=0, pp=100.0, hess=diag, temp=1.0, link=bridge
#   Fit done in 13.4s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.7s
#     OOD 170° eval done in 3.6s
#   Flushed 1648 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [413/1728] arch=resnet18, seed=42, pp=100.0, hess=diag, temp=1.0, link=bridge
#   Fit done in 13.4s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.6s
#     OOD 170° eval done in 3.7s
#   Flushed 1652 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [414/1728] arch=resnet18, seed=123, pp=100.0, hess=diag, temp=1.0, link=bridge
#   Fit done in 13.5s
#   ID eval done in 2.7s
#     OOD 15° eval done in 3.6s
#     OOD 45° eval done in 3.6s
#     OOD 80° eval done in 3.7s
#     OOD 170° eval done in 3.6s
#   Flushed 1656 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [415/1728] arch=resnet18, seed=0, pp=100.0, hess=kron, temp=0.1, link=probit
#   Fit done in 24.4s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.9s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 3.9s
#   Flushed 1660 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [416/1728] arch=resnet18, seed=42, pp=100.0, hess=kron, temp=0.1, link=probit
#   Fit done in 24.4s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.9s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.9s
#   Flushed 1664 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [417/1728] arch=resnet18, seed=123, pp=100.0, hess=kron, temp=0.1, link=probit
#   Fit done in 24.5s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.8s
#   Flushed 1668 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [418/1728] arch=resnet18, seed=0, pp=100.0, hess=kron, temp=0.1, link=bridge
#   Fit done in 24.4s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 3.9s
#   Flushed 1672 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [419/1728] arch=resnet18, seed=42, pp=100.0, hess=kron, temp=0.1, link=bridge
#   Fit done in 24.5s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.9s
#   Flushed 1676 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [420/1728] arch=resnet18, seed=123, pp=100.0, hess=kron, temp=0.1, link=bridge
#   Fit done in 24.6s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.8s
#   Flushed 1680 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [421/1728] arch=resnet18, seed=0, pp=100.0, hess=kron, temp=0.5, link=probit
#   Fit done in 24.6s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 4.0s
#     OOD 170° eval done in 3.9s
#   Flushed 1684 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [422/1728] arch=resnet18, seed=42, pp=100.0, hess=kron, temp=0.5, link=probit
#   Fit done in 24.5s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.9s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 3.9s
#   Flushed 1688 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [423/1728] arch=resnet18, seed=123, pp=100.0, hess=kron, temp=0.5, link=probit
#   Fit done in 24.5s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.9s
#   Flushed 1692 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [424/1728] arch=resnet18, seed=0, pp=100.0, hess=kron, temp=0.5, link=bridge
#   Fit done in 24.4s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.9s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 3.8s
#   Flushed 1696 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [425/1728] arch=resnet18, seed=42, pp=100.0, hess=kron, temp=0.5, link=bridge
#   Fit done in 24.6s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.9s
#   Flushed 1700 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [426/1728] arch=resnet18, seed=123, pp=100.0, hess=kron, temp=0.5, link=bridge
#   Fit done in 24.7s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.8s
#   Flushed 1704 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [427/1728] arch=resnet18, seed=0, pp=100.0, hess=kron, temp=1.0, link=probit
#   Fit done in 24.5s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.8s
#     OOD 170° eval done in 3.8s
#   Flushed 1708 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [428/1728] arch=resnet18, seed=42, pp=100.0, hess=kron, temp=1.0, link=probit
#   Fit done in 24.5s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.9s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 3.8s
#   Flushed 1712 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [429/1728] arch=resnet18, seed=123, pp=100.0, hess=kron, temp=1.0, link=probit
#   Fit done in 25.0s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.9s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 4.0s
#   Flushed 1716 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [430/1728] arch=resnet18, seed=0, pp=100.0, hess=kron, temp=1.0, link=bridge
#   Fit done in 24.3s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.9s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 3.9s
#   Flushed 1720 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [431/1728] arch=resnet18, seed=42, pp=100.0, hess=kron, temp=1.0, link=bridge
#   Fit done in 24.8s
#   ID eval done in 2.9s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 3.9s
#   Flushed 1724 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# [432/1728] arch=resnet18, seed=123, pp=100.0, hess=kron, temp=1.0, link=bridge
#   Fit done in 24.5s
#   ID eval done in 2.8s
#     OOD 15° eval done in 3.8s
#     OOD 45° eval done in 3.8s
#     OOD 80° eval done in 3.9s
#     OOD 170° eval done in 3.9s
#   Flushed 1728 rows to /kaggle/working/laplace_outputs/sensitivity_results.csv
# Experiment complete in 14954.0s
# Final results saved to /kaggle/working/laplace_outputs/sensitivity_results.csv
